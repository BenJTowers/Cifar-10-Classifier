# %%
# !git clone https://github.com/BenJTowers/Cifar-10-Classifier.git
# Out:
# Cloning into 'Cifar-10-Classifier'...
# ...

# %%
# %cd Cifar-10-Classifier
# Out:
# /content/Cifar-10-Classifier

# %%
# !git config --global user.email "benjtowers@gmail.com"
# !git config --global user.name "Ben Towers"
